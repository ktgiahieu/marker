# %%
# install dependencies
# !pip install -U torch torchvision cython
# !pip install -U 'git+https://github.com/facebookresearch/fvcore.git' 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# %%
# %reload_ext dotenv
# %dotenv

# %%
import os
AZURE_ENDPOINT = os.environ.get("AZURE_OPENAI_ENDPOINT", "YOUR_ENDPOINT_HERE")
AZURE_API_KEY = os.environ.get("AZURE_OPENAI_API_KEY", "YOUR_API_KEY_HERE")
AZURE_DEPLOYMENT_NAME = os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME", "YOUR_DEPLOYMENT_NAME_HERE") # e.g., your gpt-4o deployment
AZURE_API_VERSION = os.environ.get("AZURE_API_VERSION", "2024-05-01-preview") # Check Azure docs for the latest/best version

# %%
import subprocess

input_pdf = 'data/papers/20740_Toward_Self_Improvement.pdf'
output_dir = input_pdf.rstrip('.pdf') + "_LLM"

cmd = [
    "marker_single",
    input_pdf,
    "--output_dir", output_dir,
    "--use_llm",
    "--redo_inline_math",
    "--llm_service", "marker.services.azure_openai.AzureOpenAIService",
    "--azure_endpoint", AZURE_ENDPOINT,
    "--azure_api_key", AZURE_API_KEY,
    "--azure_deployment_name", AZURE_DEPLOYMENT_NAME,
    "--azure_api_version", AZURE_API_VERSION,
]
try:
    subprocess.run(cmd, check=True)
except subprocess.CalledProcessError as e:
    print(f"[ERROR] marker_single failed for {input_pdf}: {e}")
# Out:
# Loaded layout model s3://layout/2025_02_18 on device mps with dtype torch.float16
# Loaded texify model s3://texify/2025_02_18 on device mps with dtype torch.float16
# Loaded recognition model s3://text_recognition/2025_02_18 on device mps with dtype torch.float16
# Loaded table recognition model s3://table_recognition/2025_02_18 on device mps with dtype torch.float16
# Loaded detection model s3://text_detection/2025_02_28 on device mps with dtype torch.float16
# Loaded detection model s3://inline_math_detection/2025_02_24 on device mps with dtype torch.float16
# Recognizing layout: 100%|██████████| 5/5 [00:32<00:00,  6.49s/it]
# LLM layout relabelling: 0it [00:00, ?it/s]
# Azure API call successful. Tokens used: 9025
# LLM layout relabelling: 1it [00:03,  3.74s/it]
# Azure API call successful. Tokens used: 14667
# LLM layout relabelling: 2it [00:03,  1.66s/it]
# Azure API call successful. Tokens used: 9018
# LLM layout relabelling: 3it [00:04,  1.13s/it]
# ...

# %%
import re

# The input text containing the log messages
log_text = """
Loaded layout model s3://layout/2025_02_18 on device mps with dtype torch.float16
Loaded texify model s3://texify/2025_02_18 on device mps with dtype torch.float16Loaded recognition model s3://text_recognition/2025_02_18 on device mps with dtype torch.float16Loaded table recognition model s3://table_recognition/2025_02_18 on device mps with dtype torch.float16Loaded detection model s3://text_detection/2025_02_28 on device mps with dtype torch.float16Loaded detection model s3://inline_math_detection/2025_02_24 on device mps with dtype torch.float16
Recognizing layout: 100%|██████████| 5/5 [00:32<00:00,  6.49s/it]LLM layout relabelling: 0it [00:00, ?it/s]
Azure API call successful. Tokens used: 9025
LLM layout relabelling: 1it [00:03,  3.74s/it]
Azure API call successful. Tokens used: 14667
LLM layout relabelling: 2it [00:03,  1.66s/it]
Azure API call successful. Tokens used: 9018
LLM layout relabelling: 3it [00:04,  1.13s/it]
Azure API call successful. Tokens used: 9014
LLM layout relabelling: 4it [00:05,  1.27s/it]
Azure API call successful. Tokens used: 9001
LLM layout relabelling: 5it [00:07,  1.30s/it]
Azure API call successful. Tokens used: 9019
LLM layout relabelling: 6it [00:07,  1.28s/it]Running OCR Error Detection: 100%|██████████| 7/7 [00:06<00:00,  1.01it/s]Detecting bboxes: 100%|██████████| 7/7 [03:59<00:00, 34.14s/it]Detecting bboxes: 100%|██████████| 7/7 [02:07<00:00, 18.28s/it]Texify inference: 100%|██████████| 4/4 [02:38<00:00, 39.60s/it]Detecting bboxes: 0it [00:00, ?it/s]Recognizing tables: 100%|██████████| 2/2 [04:40<00:00, 140.15s/it]LLMTableProcessor running: 0it [00:00, ?it/s]
Azure API call successful. Tokens used: 15423
LLMTableProcessor running: 1it [00:08,  8.02s/it]
Azure API call successful. Tokens used: 9328
LLMTableProcessor running: 2it [00:12,  6.03s/it]
Azure API call successful. Tokens used: 9344
LLMTableProcessor running: 3it [00:17,  5.43s/it]
Azure API call successful. Tokens used: 15971
LLMTableProcessor running: 4it [00:18,  3.80s/it]
Azure API call successful. Tokens used: 9340
LLMTableProcessor running: 5it [00:23,  4.10s/it]
Azure API call successful. Tokens used: 17198Azure API call successful. Tokens used: 15530
LLMTableProcessor running: 6it [00:25,  3.33s/it]
Azure API call successful. Tokens used: 15043
LLMTableProcessor running: 8it [00:28,  3.58s/it]LLMTableMergeProcessor running: 0it [00:00, ?it/s]LLM processors running:   0%|          | 0/38 [00:00<?, ?it/s]
Azure API call successful. Tokens used: 21714Azure API call successful. Tokens used: 21708Azure API call successful. Tokens used: 21712
LLM processors running:   3%|▎         | 1/38 [00:10<06:27, 10.48s/it]
Azure API call successful. Tokens used: 21770
LLM processors running:  11%|█         | 4/38 [00:15<01:56,  3.43s/it]
Azure API call successful. Tokens used: 21541
LLM processors running:  13%|█▎        | 5/38 [00:17<01:32,  2.82s/it]
Azure API call successful. Tokens used: 21602
LLM processors running:  16%|█▌        | 6/38 [00:17<01:10,  2.21s/it]
Azure API call successful. Tokens used: 21973Azure API call successful. Tokens used: 21816
LLM processors running:  21%|██        | 8/38 [00:25<01:18,  2.63s/it]
Azure API call successful. Tokens used: 21844
LLM processors running:  24%|██▎       | 9/38 [00:27<01:17,  2.67s/it]
Azure API call successful. Tokens used: 21376Azure API call successful. Tokens used: 21594Azure API call successful. Tokens used: 21341
LLM processors running:  26%|██▋       | 10/38 [00:36<02:05,  4.47s/it]
Azure API call successful. Tokens used: 21676
LLM processors running:  34%|███▍      | 13/38 [00:40<01:07,  2.69s/it]
Azure API call successful. Tokens used: 21473
LLM processors running:  37%|███▋      | 14/38 [00:42<01:00,  2.53s/it]
Azure API call successful. Tokens used: 21628
LLM processors running:  39%|███▉      | 15/38 [00:43<00:50,  2.20s/it]
Azure API call successful. Tokens used: 21020
LLM processors running:  42%|████▏     | 16/38 [00:45<00:48,  2.22s/it]
Azure API call successful. Tokens used: 9238
LLM processors running:  45%|████▍     | 17/38 [00:46<00:39,  1.87s/it]
Azure API call successful. Tokens used: 14915
LLM processors running:  47%|████▋     | 18/38 [00:47<00:34,  1.73s/it]
Azure API call successful. Tokens used: 9137Azure API call successful. Tokens used: 9350
LLM processors running:  50%|█████     | 19/38 [00:50<00:36,  1.92s/it]
Azure API call successful. Tokens used: 9394
LLM processors running:  55%|█████▌    | 21/38 [00:53<00:28,  1.69s/it]
Azure API call successful. Tokens used: 9128Azure API call successful. Tokens used: 9284
LLM processors running:  61%|██████    | 23/38 [00:53<00:16,  1.07s/it]
Azure API call successful. Tokens used: 9111Azure API call successful. Tokens used: 9146
LLM processors running:  63%|██████▎   | 24/38 [00:57<00:23,  1.67s/it]
Azure API call successful. Tokens used: 9138
LLM processors running:  66%|██████▌   | 25/38 [00:57<00:16,  1.30s/it]
Azure API call successful. Tokens used: 9125Azure API call successful. Tokens used: 9163
LLM processors running:  71%|███████   | 27/38 [01:00<00:16,  1.47s/it]
Azure API call successful. Tokens used: 9241
LLM processors running:  76%|███████▋  | 29/38 [01:01<00:08,  1.04it/s]
Azure API call successful. Tokens used: 9203Azure API call successful. Tokens used: 9187
LLM processors running:  82%|████████▏ | 31/38 [01:03<00:07,  1.02s/it]
Azure API call successful. Tokens used: 9246
LLM processors running:  84%|████████▍ | 32/38 [01:05<00:07,  1.23s/it]
Azure API call successful. Tokens used: 9139Azure API call successful. Tokens used: 9220
LLM processors running:  89%|████████▉ | 34/38 [01:07<00:04,  1.02s/it]
Azure API call successful. Tokens used: 9135
LLM processors running:  92%|█████████▏| 35/38 [01:09<00:04,  1.42s/it]
Azure API call successful. Tokens used: 8857Azure API call successful. Tokens used: 9252
LLM processors running:  95%|█████████▍| 36/38 [01:11<00:02,  1.49s/it]
Azure API call successful. Tokens used: 8874
LLM processors running: 100%|██████████| 38/38 [01:12<00:00,  1.91s/it]LLMMathBlockProcessor running: 0it [00:00, ?it/s]
Azure API call successful. Tokens used: 20910
LLMMathBlockProcessor running: 1it [00:05,  5.70s/it]
Azure API call successful. Tokens used: 20985
LLMMathBlockProcessor running: 2it [00:11,  5.69s/it]
Azure API call successful. Tokens used: 21226
LLMMathBlockProcessor running: 3it [00:11,  3.27s/it]
Azure API call successful. Tokens used: 21306
LLMMathBlockProcessor running: 4it [00:12,  2.13s/it]
Azure API call successful. Tokens used: 20863Azure API call successful. Tokens used: 21030
LLMMathBlockProcessor running: 5it [00:17,  3.14s/it]
Azure API call successful. Tokens used: 21546
LLMMathBlockProcessor running: 7it [00:21,  2.74s/it]
Azure API call successful. Tokens used: 21660
LLMMathBlockProcessor running: 8it [00:25,  3.11s/it]
Azure API call successful. Tokens used: 20945
LLMMathBlockProcessor running: 9it [00:27,  2.72s/it]
Azure API call successful. Tokens used: 21481
LLMMathBlockProcessor running: 10it [00:27,  2.05s/it]
Azure API call successful. Tokens used: 21006
LLMMathBlockProcessor running: 11it [00:33,  3.04s/it]
Azure API call successful. Tokens used: 21228
LLMMathBlockProcessor running: 12it [00:33,  2.29s/it]
Azure API call successful. Tokens used: 21197
LLMMathBlockProcessor running: 13it [00:34,  1.73s/it]
Azure API call successful. Tokens used: 21056
LLMMathBlockProcessor running: 14it [00:40,  2.91s/it]
Azure API call successful. Tokens used: 21542
LLMMathBlockProcessor running: 15it [00:42,  2.72s/it]
Azure API call successful. Tokens used: 21753
LLMMathBlockProcessor running: 16it [00:43,  2.24s/it]
Azure API call successful. Tokens used: 21512
LLMMathBlockProcessor running: 17it [00:49,  3.38s/it]
Azure API call successful. Tokens used: 21288
LLMMathBlockProcessor running: 18it [00:51,  2.89s/it]
Azure API call successful. Tokens used: 21134
LLMMathBlockProcessor running: 19it [00:52,  2.49s/it]
Azure API call successful. Tokens used: 21115
LLMMathBlockProcessor running: 20it [00:54,  2.31s/it]
Azure API call successful. Tokens used: 21245
LLMMathBlockProcessor running: 21it [00:58,  2.69s/it]
Azure API call successful. Tokens used: 21037Azure API call successful. Tokens used: 21202
LLMMathBlockProcessor running: 22it [00:59,  2.27s/it]
Azure API call successful. Tokens used: 15052
LLMMathBlockProcessor running: 24it [01:02,  1.80s/it]
Azure API call successful. Tokens used: 15127
LLMMathBlockProcessor running: 25it [01:04,  1.87s/it]
Azure API call successful. Tokens used: 20756
LLMMathBlockProcessor running: 26it [01:04,  1.59s/it]
Azure API call successful. Tokens used: 20856
LLMMathBlockProcessor running: 27it [01:06,  1.69s/it]
Azure API call successful. Tokens used: 20805
LLMMathBlockProcessor running: 28it [01:08,  1.61s/it]
Azure API call successful. Tokens used: 20922
LLMMathBlockProcessor running: 29it [01:09,  1.58s/it]
Azure API call successful. Tokens used: 20906
LLMMathBlockProcessor running: 30it [01:11,  1.62s/it]
Azure API call successful. Tokens used: 21011
LLMMathBlockProcessor running: 31it [01:13,  1.72s/it]
Azure API call successful. Tokens used: 15266
LLMMathBlockProcessor running: 32it [01:14,  1.57s/it]
Azure API call successful. Tokens used: 15196
LLMMathBlockProcessor running: 33it [01:16,  1.51s/it]
Azure API call successful. Tokens used: 15282
LLMMathBlockProcessor running: 34it [01:18,  1.90s/it]
Azure API call successful. Tokens used: 21254
LLMMathBlockProcessor running: 35it [01:21,  2.04s/it]
Azure API call successful. Tokens used: 21476Azure API call successful. Tokens used: 20864
LLMMathBlockProcessor running: 36it [01:24,  2.37s/it]
Azure API call successful. Tokens used: 21068
LLMMathBlockProcessor running: 38it [01:27,  2.08s/it]
Azure API call successful. Tokens used: 21124
LLMMathBlockProcessor running: 39it [01:30,  2.11s/it]
Azure API call successful. Tokens used: 21099
LLMMathBlockProcessor running: 40it [01:30,  1.75s/it]
Azure API call successful. Tokens used: 21486Azure API call successful. Tokens used: 21135
LLMMathBlockProcessor running: 41it [01:35,  2.57s/it]
Azure API call successful. Tokens used: 21182
LLMMathBlockProcessor running: 43it [01:37,  1.90s/it]
Azure API call successful. Tokens used: 20888
LLMMathBlockProcessor running: 44it [01:39,  2.00s/it]
Azure API call successful. Tokens used: 21072
LLMMathBlockProcessor running: 45it [01:41,  1.94s/it]
Azure API call successful. Tokens used: 20857
LLMMathBlockProcessor running: 46it [01:42,  1.57s/it]
Azure API call successful. Tokens used: 15046
LLMMathBlockProcessor running: 47it [01:45,  1.99s/it]
Azure API call successful. Tokens used: 21144
LLMMathBlockProcessor running: 48it [01:47,  1.90s/it]
Azure API call successful. Tokens used: 21172
LLMMathBlockProcessor running: 49it [01:48,  1.80s/it]
Azure API call successful. Tokens used: 20865
LLMMathBlockProcessor running: 50it [01:48,  1.40s/it]
Azure API call successful. Tokens used: 20984
LLMMathBlockProcessor running: 51it [01:52,  2.00s/it]
Azure API call successful. Tokens used: 20789
LLMMathBlockProcessor running: 52it [01:52,  1.52s/it]
Azure API call successful. Tokens used: 15022
LLMMathBlockProcessor running: 53it [01:55,  1.94s/it]
Azure API call successful. Tokens used: 20813
LLMMathBlockProcessor running: 54it [01:56,  1.66s/it]
Azure API call successful. Tokens used: 21081
LLMMathBlockProcessor running: 55it [01:58,  1.74s/it]
Azure API call successful. Tokens used: 15130
LLMMathBlockProcessor running: 56it [02:00,  1.64s/it]
Azure API call successful. Tokens used: 15035
LLMMathBlockProcessor running: 57it [02:00,  1.23s/it]
Azure API call successful. Tokens used: 15080
LLMMathBlockProcessor running: 58it [02:03,  1.71s/it]
Azure API call successful. Tokens used: 20722
LLMMathBlockProcessor running: 59it [02:03,  1.39s/it]
Azure API call successful. Tokens used: 15031
LLMMathBlockProcessor running: 60it [02:06,  1.79s/it]
Azure API call successful. Tokens used: 15045Azure API call successful. Tokens used: 9363
LLMMathBlockProcessor running: 61it [02:06,  1.39s/it]
Azure API call successful. Tokens used: 20734
LLMMathBlockProcessor running: 63it [02:10,  1.48s/it]
Azure API call successful. Tokens used: 15160
LLMMathBlockProcessor running: 64it [02:11,  1.49s/it]
Azure API call successful. Tokens used: 20761
LLMMathBlockProcessor running: 65it [02:12,  1.44s/it]
Azure API call successful. Tokens used: 21342
LLMMathBlockProcessor running: 66it [02:14,  1.55s/it]
Azure API call successful. Tokens used: 21389
LLMMathBlockProcessor running: 67it [02:19,  2.33s/it]
Azure API call successful. Tokens used: 21299
LLMMathBlockProcessor running: 68it [02:19,  1.88s/it]
Azure API call successful. Tokens used: 21513
LLMMathBlockProcessor running: 69it [02:22,  2.12s/it]
Azure API call successful. Tokens used: 20867
LLMMathBlockProcessor running: 70it [02:23,  1.80s/it]
Azure API call successful. Tokens used: 9325
LLMMathBlockProcessor running: 71it [02:25,  1.81s/it]
Azure API call successful. Tokens used: 21261
LLMMathBlockProcessor running: 72it [02:26,  1.68s/it]
Azure API call successful. Tokens used: 21037Azure API call successful. Tokens used: 20867Azure API call successful. Tokens used: 9359
LLMMathBlockProcessor running: 73it [02:30,  2.15s/it]
Azure API call successful. Tokens used: 9398
LLMMathBlockProcessor running: 76it [02:33,  1.60s/it]
Azure API call successful. Tokens used: 9389
LLMMathBlockProcessor running: 77it [02:34,  1.38s/it]
Azure API call successful. Tokens used: 20871
LLMMathBlockProcessor running: 78it [02:35,  1.37s/it]
Azure API call successful. Tokens used: 9366
LLMMathBlockProcessor running: 79it [02:37,  1.49s/it]
Azure API call successful. Tokens used: 9357
LLMMathBlockProcessor running: 80it [02:38,  1.41s/it]
Azure API call successful. Tokens used: 21498
LLMMathBlockProcessor running: 81it [02:41,  1.82s/it]
Azure API call successful. Tokens used: 20783
LLMMathBlockProcessor running: 82it [02:43,  1.74s/it]
Azure API call successful. Tokens used: 21065
LLMMathBlockProcessor running: 83it [02:43,  1.45s/it]
Azure API call successful. Tokens used: 15043
LLMMathBlockProcessor running: 84it [02:47,  2.01s/it]
Azure API call successful. Tokens used: 21034
LLMMathBlockProcessor running: 85it [02:48,  1.93s/it]
Azure API call successful. Tokens used: 21460
LLMMathBlockProcessor running: 86it [02:49,  1.56s/it]
Azure API call successful. Tokens used: 21033
LLMMathBlockProcessor running: 87it [02:54,  2.47s/it]
Azure API call successful. Tokens used: 21285
LLMMathBlockProcessor running: 88it [02:56,  2.29s/it]
Azure API call successful. Tokens used: 21781
LLMMathBlockProcessor running: 89it [02:56,  1.69s/it]
Azure API call successful. Tokens used: 9363
LLMMathBlockProcessor running: 90it [02:57,  1.64s/it]
Azure API call successful. Tokens used: 9340Azure API call successful. Tokens used: 20971
LLMMathBlockProcessor running: 91it [03:00,  2.08s/it]
Azure API call successful. Tokens used: 9331
LLMMathBlockProcessor running: 93it [03:04,  2.02s/it]
Azure API call successful. Tokens used: 21118
LLMMathBlockProcessor running: 94it [03:07,  2.16s/it]
Azure API call successful. Tokens used: 21080Azure API call successful. Tokens used: 15041
LLMMathBlockProcessor running: 96it [03:08,  1.33s/it]
Azure API call successful. Tokens used: 20708
LLMMathBlockProcessor running: 97it [03:12,  2.12s/it]
Azure API call successful. Tokens used: 21652
LLMMathBlockProcessor running: 98it [03:17,  2.98s/it]
Azure API call successful. Tokens used: 21062
LLMMathBlockProcessor running: 99it [03:17,  2.23s/it]
Azure API call successful. Tokens used: 21997
LLMMathBlockProcessor running: 100it [03:22,  2.90s/it]
Azure API call successful. Tokens used: 21167
LLMMathBlockProcessor running: 101it [03:23,  2.41s/it]
Azure API call successful. Tokens used: 9335
LLMMathBlockProcessor running: 102it [03:25,  2.18s/it]
Azure API call successful. Tokens used: 21476
LLMMathBlockProcessor running: 103it [03:25,  1.65s/it]
Azure API call successful. Tokens used: 20791
LLMMathBlockProcessor running: 104it [03:27,  1.82s/it]
Azure API call successful. Tokens used: 9334
LLMMathBlockProcessor running: 105it [03:31,  2.24s/it]
Azure API call successful. Tokens used: 21082
LLMMathBlockProcessor running: 106it [03:31,  1.75s/it]
Azure API call successful. Tokens used: 21332
LLMMathBlockProcessor running: 107it [03:32,  1.42s/it]
Azure API call successful. Tokens used: 9334
LLMMathBlockProcessor running: 108it [03:33,  1.18s/it]
Azure API call successful. Tokens used: 21189
LLMMathBlockProcessor running: 109it [03:38,  2.32s/it]
Azure API call successful. Tokens used: 21083
LLMMathBlockProcessor running: 110it [03:38,  1.73s/it]
Azure API call successful. Tokens used: 21533
LLMMathBlockProcessor running: 111it [03:40,  1.79s/it]
Azure API call successful. Tokens used: 9336
LLMMathBlockProcessor running: 112it [03:43,  2.18s/it]
Azure API call successful. Tokens used: 20976
LLMMathBlockProcessor running: 113it [03:43,  1.60s/it]
Azure API call successful. Tokens used: 21142
LLMMathBlockProcessor running: 114it [03:44,  1.26s/it]
Azure API call successful. Tokens used: 9315
LLMMathBlockProcessor running: 115it [03:46,  1.65s/it]
Azure API call successful. Tokens used: 21180
LLMMathBlockProcessor running: 116it [03:49,  2.12s/it]
Azure API call successful. Tokens used: 21139
LLMMathBlockProcessor running: 117it [03:50,  1.69s/it]
Azure API call successful. Tokens used: 20976
LLMMathBlockProcessor running: 118it [03:52,  1.65s/it]
Azure API call successful. Tokens used: 9330
LLMMathBlockProcessor running: 119it [03:52,  1.36s/it]
Azure API call successful. Tokens used: 20894
LLMMathBlockProcessor running: 120it [03:55,  1.73s/it]
Azure API call successful. Tokens used: 20794
LLMMathBlockProcessor running: 121it [03:57,  1.70s/it]
Azure API call successful. Tokens used: 21204
LLMMathBlockProcessor running: 122it [03:59,  1.96s/it]
Azure API call successful. Tokens used: 20742
LLMMathBlockProcessor running: 123it [04:01,  1.79s/it]
Azure API call successful. Tokens used: 21164
LLMMathBlockProcessor running: 124it [04:02,  1.72s/it]
Azure API call successful. Tokens used: 20759
LLMMathBlockProcessor running: 125it [04:03,  1.51s/it]
Azure API call successful. Tokens used: 15065
LLMMathBlockProcessor running: 126it [04:05,  1.59s/it]
Azure API call successful. Tokens used: 9368
LLMMathBlockProcessor running: 127it [04:06,  1.54s/it]
Azure API call successful. Tokens used: 20819
LLMMathBlockProcessor running: 128it [04:08,  1.66s/it]
Azure API call successful. Tokens used: 9351
LLMMathBlockProcessor running: 129it [04:10,  1.60s/it]
Azure API call successful. Tokens used: 20989
LLMMathBlockProcessor running: 130it [04:10,  1.20s/it]
Azure API call successful. Tokens used: 15012
LLMMathBlockProcessor running: 131it [04:13,  1.83s/it]
Azure API call successful. Tokens used: 21102
LLMMathBlockProcessor running: 132it [04:14,  1.56s/it]
Azure API call successful. Tokens used: 21070
LLMMathBlockProcessor running: 133it [04:15,  1.30s/it]
Azure API call successful. Tokens used: 15024
LLMMathBlockProcessor running: 134it [04:17,  1.47s/it]
Azure API call successful. Tokens used: 9317
LLMMathBlockProcessor running: 135it [04:18,  1.36s/it]
Azure API call successful. Tokens used: 15104
LLMMathBlockProcessor running: 136it [04:18,  1.05s/it]
Azure API call successful. Tokens used: 15015
LLMMathBlockProcessor running: 137it [04:20,  1.26s/it]
Azure API call successful. Tokens used: 9383Azure API call successful. Tokens used: 15069
LLMMathBlockProcessor running: 138it [04:22,  1.41s/it]
Azure API call successful. Tokens used: 9341
LLMMathBlockProcessor running: 140it [04:23,  1.01it/s]
Azure API call successful. Tokens used: 15009
LLMMathBlockProcessor running: 141it [04:25,  1.33s/it]
Azure API call successful. Tokens used: 20795
LLMMathBlockProcessor running: 142it [04:26,  1.23s/it]
Azure API call successful. Tokens used: 15130
LLMMathBlockProcessor running: 143it [04:27,  1.04s/it]
Azure API call successful. Tokens used: 20800
LLMMathBlockProcessor running: 144it [04:30,  1.63s/it]
Azure API call successful. Tokens used: 20728
LLMMathBlockProcessor running: 145it [04:30,  1.32s/it]
Azure API call successful. Tokens used: 20861
LLMMathBlockProcessor running: 146it [04:31,  1.07s/it]
Azure API call successful. Tokens used: 20738
LLMMathBlockProcessor running: 147it [04:34,  1.71s/it]
Azure API call successful. Tokens used: 15050
LLMMathBlockProcessor running: 148it [04:35,  1.41s/it]
Azure API call successful. Tokens used: 20954
LLMMathBlockProcessor running: 149it [04:35,  1.13s/it]
Azure API call successful. Tokens used: 9294
LLMMathBlockProcessor running: 150it [04:38,  1.55s/it]
Azure API call successful. Tokens used: 9308Azure API call successful. Tokens used: 20697
LLMMathBlockProcessor running: 151it [04:38,  1.25s/it]
Azure API call successful. Tokens used: 9296
LLMMathBlockProcessor running: 153it [04:40,  1.20s/it]
Azure API call successful. Tokens used: 15052
LLMMathBlockProcessor running: 154it [04:42,  1.24s/it]
Azure API call successful. Tokens used: 9299Azure API call successful. Tokens used: 20880
LLMMathBlockProcessor running: 156it [04:45,  1.26s/it]
Azure API call successful. Tokens used: 15056
LLMMathBlockProcessor running: 157it [04:45,  1.06s/it]
Azure API call successful. Tokens used: 20760
LLMMathBlockProcessor running: 158it [04:49,  1.77s/it]
Azure API call successful. Tokens used: 20995
LLMMathBlockProcessor running: 159it [04:50,  1.83s/it]
Saved markdown to data/papers/20740_Toward_Self_Improvement_LLM/20740_Toward_Self_ImprovementTotal time: 1268.7391691207886
"""

# Regular expression to find the lines and extract the token number
# It looks for the literal string "Azure API call successful. Tokens used: "
# followed by one or more digits (\d+), which are captured in a group ().
pattern = r"Azure API call successful\. Tokens used: (\d+)"

# Find all matches of the pattern in the log text
# re.findall returns a list of all captured groups (the numbers as strings)
token_strings = re.findall(pattern, log_text)

# Initialize the total sum
total_tokens = 0

# Iterate through the list of extracted token strings
for token_str in token_strings:
    try:
        # Convert the string to an integer and add it to the total sum
        total_tokens += int(token_str)
    except ValueError:
        # Handle cases where conversion might fail (though unlikely with this pattern)
        print(f"Warning: Could not convert '{token_str}' to an integer.")

# Print the list of extracted tokens (optional)
# print("Extracted Tokens:", token_strings)

# Print the total number of tokens found
print(f"Found {len(token_strings)} instances.")

# Print the final calculated sum
print(f"Total tokens used: {total_tokens}")
# Out:
# Found 211 instances.
# Total tokens used: 3623743

# %%
import subprocess

input_pdf = 'data/papers/20740_Toward_Self_Improvement.pdf'
output_dir = input_pdf.rstrip('.pdf') + "_paginate_ocr"

cmd = [
    "marker_single",
    input_pdf,
    "--output_dir", output_dir,
    "--paginate_output",
    "--force_ocr",
]
try:
    subprocess.run(cmd, check=True)
except subprocess.CalledProcessError as e:
    print(f"[ERROR] marker_single failed for {input_pdf}: {e}")
# Out:
# Loaded layout model s3://layout/2025_02_18 on device mps with dtype torch.float16
# Loaded texify model s3://texify/2025_02_18 on device mps with dtype torch.float16
# Loaded recognition model s3://text_recognition/2025_02_18 on device mps with dtype torch.float16
# Loaded table recognition model s3://table_recognition/2025_02_18 on device mps with dtype torch.float16
# Loaded detection model s3://text_detection/2025_02_28 on device mps with dtype torch.float16
# Loaded detection model s3://inline_math_detection/2025_02_24 on device mps with dtype torch.float16
# ...
# Recognizing Text:   0%|          | 0/39 [00:00<?, ?it/s]

# %%
import re

# The input text containing the log messages
log_text = """2025-04-30 08:25:30.886366: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
E0000 00:00:1746001530.920129    9396 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
E0000 00:00:1746001530.930529    9396 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
2025-04-30 08:25:30.961366: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
Loaded layout model s3://layout/2025_02_18 on device cuda with dtype torch.float16
Loaded texify model s3://texify/2025_02_18 on device cuda with dtype torch.float16
Loaded recognition model s3://text_recognition/2025_02_18 on device cuda with dtype torch.float16
Loaded table recognition model s3://table_recognition/2025_02_18 on device cuda with dtype torch.float16
Loaded detection model s3://text_detection/2025_02_28 on device cuda with dtype torch.float16
Loaded detection model s3://inline_math_detection/2025_02_24 on device cuda with dtype torch.float16
Recognizing layout: 100% 5/5 [00:04<00:00,  1.04it/s]
LLM layout relabelling: 0it [00:00, ?it/s]Azure API call successful. Total tokens used: 745 (prompt: 717, completion: 28).
LLM layout relabelling: 1it [00:01,  1.89s/it]Azure API call successful. Total tokens used: 725 (prompt: 698, completion: 27).
LLM layout relabelling: 2it [00:02,  1.09it/s]Azure API call successful. Total tokens used: 879 (prompt: 854, completion: 25).
LLM layout relabelling: 3it [00:02,  1.47it/s]Azure API call successful. Total tokens used: 726 (prompt: 704, completion: 22).
LLM layout relabelling: 4it [00:04,  1.10s/it]Azure API call successful. Total tokens used: 740 (prompt: 704, completion: 36).
LLM layout relabelling: 5it [00:05,  1.32s/it]Azure API call successful. Total tokens used: 755 (prompt: 721, completion: 34).
LLM layout relabelling: 6it [00:06,  1.13s/it]Azure API call successful. Total tokens used: 738 (prompt: 704, completion: 34).
LLM layout relabelling: 7it [00:07,  1.13s/it]Azure API call successful. Total tokens used: 729 (prompt: 707, completion: 22).
LLM layout relabelling: 8it [00:08,  1.05s/it]
Running OCR Error Detection: 100% 7/7 [00:00<00:00, 41.30it/s]
Detecting bboxes: 100% 7/7 [00:06<00:00,  1.13it/s]
Detecting bboxes: 100% 7/7 [00:05<00:00,  1.30it/s]
Texify inference: 100% 4/4 [00:03<00:00,  1.01it/s]
Detecting bboxes: 0it [00:00, ?it/s]
Recognizing tables: 100% 2/2 [00:01<00:00,  1.92it/s]
LLMTableProcessor running: 0it [00:00, ?it/s]Azure API call successful. Total tokens used: 1956 (prompt: 1914, completion: 42).
LLMTableProcessor running: 1it [00:03,  3.66s/it]Azure API call successful. Total tokens used: 1166 (prompt: 1138, completion: 28).
LLMTableProcessor running: 2it [00:06,  2.92s/it]Azure API call successful. Total tokens used: 1595 (prompt: 1199, completion: 396).
LLMTableProcessor running: 3it [00:07,  2.32s/it]Azure API call successful. Total tokens used: 973 (prompt: 928, completion: 45).
LLMTableProcessor running: 4it [00:08,  1.68s/it]Azure API call successful. Total tokens used: 1354 (prompt: 1324, completion: 30).
LLMTableProcessor running: 5it [00:10,  1.75s/it]Azure API call successful. Total tokens used: 1146 (prompt: 1112, completion: 34).
LLMTableProcessor running: 6it [00:13,  2.16s/it]Azure API call successful. Total tokens used: 1093 (prompt: 932, completion: 161).
LLMTableProcessor running: 7it [00:14,  2.00s/it]Azure API call successful. Total tokens used: 2044 (prompt: 1415, completion: 629).
LLMTableProcessor running: 8it [00:22,  2.77s/it]
LLMTableMergeProcessor running: 0it [00:00, ?it/s]
LLM processors running:   0% 0/37 [00:00<?, ?it/s]Azure API call successful. Total tokens used: 2405 (prompt: 1926, completion: 479).
Azure API call successful. Total tokens used: 2346 (prompt: 1915, completion: 431).
LLM processors running:   3% 1/37 [00:28<17:21, 28.92s/it]Azure API call successful. Total tokens used: 2477 (prompt: 1977, completion: 500).
Azure API call successful. Total tokens used: 2317 (prompt: 1865, completion: 452).
Azure API call successful. Total tokens used: 2464 (prompt: 1978, completion: 486).
LLM processors running:   8% 3/37 [00:52<09:13, 16.27s/it]Azure API call successful. Total tokens used: 2365 (prompt: 1891, completion: 474).
LLM processors running:  16% 6/37 [00:57<03:45,  7.29s/it]Azure API call successful. Total tokens used: 2497 (prompt: 1967, completion: 530).
Azure API call successful. Total tokens used: 2508 (prompt: 2008, completion: 500).
Azure API call successful. Total tokens used: 2063 (prompt: 1750, completion: 313).
Azure API call successful. Total tokens used: 2125 (prompt: 1771, completion: 354).
Azure API call successful. Total tokens used: 2725 (prompt: 2081, completion: 644).
LLM processors running:  19% 7/37 [01:33<06:50, 13.69s/it]Azure API call successful. Total tokens used: 2348 (prompt: 1884, completion: 464).
LLM processors running:  32% 12/37 [01:34<02:15,  5.43s/it]Azure API call successful. Total tokens used: 2383 (prompt: 1912, completion: 471).
LLM processors running:  35% 13/37 [01:35<01:53,  4.74s/it]Azure API call successful. Total tokens used: 1773 (prompt: 1602, completion: 171).
Azure API call successful. Total tokens used: 2308 (prompt: 1899, completion: 409).
Azure API call successful. Total tokens used: 1133 (prompt: 1054, completion: 79).
Azure API call successful. Total tokens used: 968 (prompt: 897, completion: 71).
Azure API call successful. Total tokens used: 2217 (prompt: 1828, completion: 389).
LLM processors running:  38% 14/37 [01:50<02:29,  6.52s/it]Azure API call successful. Total tokens used: 903 (prompt: 860, completion: 43).
Azure API call successful. Total tokens used: 1010 (prompt: 905, completion: 105).
LLM processors running:  51% 19/37 [01:52<00:56,  3.12s/it]Azure API call successful. Total tokens used: 909 (prompt: 866, completion: 43).
Azure API call successful. Total tokens used: 925 (prompt: 867, completion: 58).
LLM processors running:  57% 21/37 [01:53<00:39,  2.46s/it]Azure API call successful. Total tokens used: 1004 (prompt: 909, completion: 95).
LLM processors running:  62% 23/37 [01:54<00:27,  2.00s/it]Azure API call successful. Total tokens used: 916 (prompt: 869, completion: 47).
Azure API call successful. Total tokens used: 929 (prompt: 869, completion: 60).
Azure API call successful. Total tokens used: 909 (prompt: 867, completion: 42).
LLM processors running:  65% 24/37 [01:56<00:26,  2.06s/it]Azure API call successful. Total tokens used: 949 (prompt: 886, completion: 63).
LLM processors running:  73% 27/37 [01:58<00:14,  1.40s/it]Azure API call successful. Total tokens used: 897 (prompt: 861, completion: 36).
LLM processors running:  76% 28/37 [01:58<00:11,  1.25s/it]Azure API call successful. Total tokens used: 944 (prompt: 883, completion: 61).
LLM processors running:  78% 29/37 [01:59<00:08,  1.10s/it]Azure API call successful. Total tokens used: 921 (prompt: 872, completion: 49).
Azure API call successful. Total tokens used: 921 (prompt: 863, completion: 58).
LLM processors running:  81% 30/37 [02:01<00:09,  1.36s/it]Azure API call successful. Total tokens used: 914 (prompt: 869, completion: 45).
Azure API call successful. Total tokens used: 929 (prompt: 877, completion: 52).
Azure API call successful. Total tokens used: 935 (prompt: 868, completion: 67).
Azure API call successful. Total tokens used: 650 (prompt: 615, completion: 35).
Azure API call successful. Total tokens used: 998 (prompt: 897, completion: 101).
LLM processors running:  86% 32/37 [02:09<00:11,  2.32s/it]Azure API call successful. Total tokens used: 936 (prompt: 872, completion: 64).
LLM processors running: 100% 37/37 [02:09<00:00,  3.51s/it]
LLMMathBlockProcessor running: 0it [00:00, ?it/s]Azure API call successful. Total tokens used: 1561 (prompt: 1459, completion: 102).
LLMMathBlockProcessor running: 1it [00:04,  4.23s/it]Azure API call successful. Total tokens used: 1677 (prompt: 1513, completion: 164).
LLMMathBlockProcessor running: 2it [00:04,  2.15s/it]Azure API call successful. Total tokens used: 1920 (prompt: 1643, completion: 277).
LLMMathBlockProcessor running: 3it [00:07,  2.19s/it]Azure API call successful. Total tokens used: 1719 (prompt: 1511, completion: 208).
LLMMathBlockProcessor running: 4it [00:09,  2.31s/it]Azure API call successful. Total tokens used: 1560 (prompt: 1463, completion: 97).
LLMMathBlockProcessor running: 5it [00:10,  1.88s/it]Azure API call successful. Total tokens used: 1986 (prompt: 1651, completion: 335).
LLMMathBlockProcessor running: 6it [00:11,  1.54s/it]Azure API call successful. Total tokens used: 2257 (prompt: 1808, completion: 449).
LLMMathBlockProcessor running: 7it [00:18,  3.26s/it]Azure API call successful. Total tokens used: 2266 (prompt: 1811, completion: 455).
LLMMathBlockProcessor running: 8it [00:19,  2.53s/it]Azure API call successful. Total tokens used: 2468 (prompt: 1925, completion: 543).
LLMMathBlockProcessor running: 9it [00:21,  2.31s/it]Azure API call successful. Total tokens used: 1590 (prompt: 1445, completion: 145).
LLMMathBlockProcessor running: 10it [00:22,  1.88s/it]Azure API call successful. Total tokens used: 2098 (prompt: 1721, completion: 377).
LLMMathBlockProcessor running: 11it [00:26,  2.49s/it]Azure API call successful. Total tokens used: 1728 (prompt: 1544, completion: 184).
LLMMathBlockProcessor running: 12it [00:28,  2.34s/it]Azure API call successful. Total tokens used: 1872 (prompt: 1613, completion: 259).
Azure API call successful. Total tokens used: 1744 (prompt: 1542, completion: 202).
LLMMathBlockProcessor running: 14it [00:33,  2.48s/it]Azure API call successful. Total tokens used: 2515 (prompt: 1938, completion: 577).
LLMMathBlockProcessor running: 15it [00:34,  2.26s/it]Azure API call successful. Total tokens used: 2298 (prompt: 1829, completion: 469).
LLMMathBlockProcessor running: 16it [00:39,  2.78s/it]Azure API call successful. Total tokens used: 2137 (prompt: 1743, completion: 394).
LLMMathBlockProcessor running: 17it [00:39,  2.14s/it]Azure API call successful. Total tokens used: 1950 (prompt: 1628, completion: 322).
LLMMathBlockProcessor running: 18it [00:41,  2.18s/it]Azure API call successful. Total tokens used: 1843 (prompt: 1601, completion: 242).
LLMMathBlockProcessor running: 19it [00:45,  2.51s/it]Azure API call successful. Total tokens used: 1994 (prompt: 1644, completion: 350).
LLMMathBlockProcessor running: 20it [00:48,  2.78s/it]Azure API call successful. Total tokens used: 2098 (prompt: 1734, completion: 364).
LLMMathBlockProcessor running: 21it [00:49,  2.22s/it]Azure API call successful. Total tokens used: 1851 (prompt: 1554, completion: 297).
LLMMathBlockProcessor running: 22it [00:50,  1.95s/it]Azure API call successful. Total tokens used: 1293 (prompt: 1229, completion: 64).
LLMMathBlockProcessor running: 23it [00:51,  1.70s/it]Azure API call successful. Total tokens used: 1742 (prompt: 1523, completion: 219).
LLMMathBlockProcessor running: 24it [00:53,  1.73s/it]Azure API call successful. Total tokens used: 1515 (prompt: 1416, completion: 99).
LLMMathBlockProcessor running: 25it [00:53,  1.27s/it]Azure API call successful. Total tokens used: 1334 (prompt: 1243, completion: 91).
LLMMathBlockProcessor running: 26it [00:54,  1.20s/it]Azure API call successful. Total tokens used: 1559 (prompt: 1459, completion: 100).
LLMMathBlockProcessor running: 27it [00:58,  1.99s/it]Azure API call successful. Total tokens used: 1545 (prompt: 1446, completion: 99).
LLMMathBlockProcessor running: 28it [00:59,  1.60s/it]Azure API call successful. Total tokens used: 1679 (prompt: 1516, completion: 163).
LLMMathBlockProcessor running: 29it [01:02,  1.88s/it]Azure API call successful. Total tokens used: 1615 (prompt: 1484, completion: 131).
LLMMathBlockProcessor running: 30it [01:03,  1.86s/it]Azure API call successful. Total tokens used: 1736 (prompt: 1545, completion: 191).
LLMMathBlockProcessor running: 31it [01:05,  1.76s/it]Azure API call successful. Total tokens used: 1458 (prompt: 1312, completion: 146).
LLMMathBlockProcessor running: 32it [01:05,  1.42s/it]Azure API call successful. Total tokens used: 1424 (prompt: 1297, completion: 127).
LLMMathBlockProcessor running: 33it [01:07,  1.50s/it]Azure API call successful. Total tokens used: 1548 (prompt: 1344, completion: 204).
LLMMathBlockProcessor running: 34it [01:10,  1.78s/it]Azure API call successful. Total tokens used: 2010 (prompt: 1674, completion: 336).
LLMMathBlockProcessor running: 35it [01:13,  2.23s/it]Azure API call successful. Total tokens used: 1635 (prompt: 1471, completion: 164).
LLMMathBlockProcessor running: 36it [01:13,  1.73s/it]Azure API call successful. Total tokens used: 2217 (prompt: 1763, completion: 454).
LLMMathBlockProcessor running: 37it [01:16,  1.87s/it]Azure API call successful. Total tokens used: 1778 (prompt: 1562, completion: 216).
LLMMathBlockProcessor running: 38it [01:18,  1.89s/it]Azure API call successful. Total tokens used: 1831 (prompt: 1580, completion: 251).
LLMMathBlockProcessor running: 39it [01:22,  2.51s/it]Azure API call successful. Total tokens used: 1823 (prompt: 1566, completion: 257).
LLMMathBlockProcessor running: 40it [01:22,  1.84s/it]Azure API call successful. Total tokens used: 2156 (prompt: 1750, completion: 406).
LLMMathBlockProcessor running: 41it [01:25,  2.25s/it]Azure API call successful. Total tokens used: 1820 (prompt: 1583, completion: 237).
LLMMathBlockProcessor running: 42it [01:27,  2.13s/it]Azure API call successful. Total tokens used: 1913 (prompt: 1620, completion: 293).
LLMMathBlockProcessor running: 43it [01:27,  1.60s/it]Azure API call successful. Total tokens used: 1771 (prompt: 1535, completion: 236).
LLMMathBlockProcessor running: 44it [01:31,  2.32s/it]Azure API call successful. Total tokens used: 1599 (prompt: 1456, completion: 143).
LLMMathBlockProcessor running: 45it [01:32,  1.72s/it]Azure API call successful. Total tokens used: 1664 (prompt: 1460, completion: 204).
LLMMathBlockProcessor running: 46it [01:32,  1.30s/it]Azure API call successful. Total tokens used: 1284 (prompt: 1230, completion: 54).
LLMMathBlockProcessor running: 47it [01:35,  1.73s/it]Azure API call successful. Total tokens used: 1785 (prompt: 1550, completion: 235).
LLMMathBlockProcessor running: 48it [01:37,  1.89s/it]Azure API call successful. Total tokens used: 1880 (prompt: 1596, completion: 284).
LLMMathBlockProcessor running: 49it [01:38,  1.80s/it]Azure API call successful. Total tokens used: 1564 (prompt: 1460, completion: 104).
Azure API call successful. Total tokens used: 1538 (prompt: 1439, completion: 99).
LLMMathBlockProcessor running: 51it [01:41,  1.66s/it]Azure API call successful. Total tokens used: 1725 (prompt: 1537, completion: 188).
LLMMathBlockProcessor running: 52it [01:42,  1.28s/it]Azure API call successful. Total tokens used: 1261 (prompt: 1225, completion: 36).
LLMMathBlockProcessor running: 53it [01:44,  1.48s/it]Azure API call successful. Total tokens used: 1860 (prompt: 1565, completion: 295).
LLMMathBlockProcessor running: 54it [01:44,  1.22s/it]Azure API call successful. Total tokens used: 1275 (prompt: 1225, completion: 50).
LLMMathBlockProcessor running: 55it [01:46,  1.50s/it]Azure API call successful. Total tokens used: 1319 (prompt: 1244, completion: 75).
LLMMathBlockProcessor running: 56it [01:46,  1.11s/it]Azure API call successful. Total tokens used: 1543 (prompt: 1437, completion: 106).
LLMMathBlockProcessor running: 57it [01:49,  1.41s/it]Azure API call successful. Total tokens used: 1094 (prompt: 1045, completion: 49).
LLMMathBlockProcessor running: 58it [01:49,  1.16s/it]Azure API call successful. Total tokens used: 1472 (prompt: 1409, completion: 63).
LLMMathBlockProcessor running: 59it [01:49,  1.15it/s]Azure API call successful. Total tokens used: 1322 (prompt: 1245, completion: 77).
LLMMathBlockProcessor running: 60it [01:51,  1.06s/it]Azure API call successful. Total tokens used: 1306 (prompt: 1229, completion: 77).
LLMMathBlockProcessor running: 61it [01:51,  1.11it/s]Azure API call successful. Total tokens used: 1479 (prompt: 1419, completion: 60).
LLMMathBlockProcessor running: 62it [01:54,  1.43s/it]Azure API call successful. Total tokens used: 1279 (prompt: 1224, completion: 55).
LLMMathBlockProcessor running: 63it [01:55,  1.32s/it]Azure API call successful. Total tokens used: 1352 (prompt: 1261, completion: 91).
LLMMathBlockProcessor running: 64it [01:56,  1.22s/it]Azure API call successful. Total tokens used: 1486 (prompt: 1419, completion: 67).
LLMMathBlockProcessor running: 65it [01:58,  1.44s/it]Azure API call successful. Total tokens used: 2058 (prompt: 1663, completion: 395).
LLMMathBlockProcessor running: 66it [02:03,  2.49s/it]Azure API call successful. Total tokens used: 2005 (prompt: 1673, completion: 332).
LLMMathBlockProcessor running: 67it [02:05,  2.33s/it]Azure API call successful. Total tokens used: 2148 (prompt: 1753, completion: 395).
LLMMathBlockProcessor running: 68it [02:08,  2.59s/it]Azure API call successful. Total tokens used: 2276 (prompt: 1793, completion: 483).
LLMMathBlockProcessor running: 69it [02:11,  2.75s/it]Azure API call successful. Total tokens used: 1533 (prompt: 1449, completion: 84).
LLMMathBlockProcessor running: 70it [02:12,  2.15s/it]Azure API call successful. Total tokens used: 1095 (prompt: 1051, completion: 44).
LLMMathBlockProcessor running: 71it [02:13,  1.88s/it]Azure API call successful. Total tokens used: 1954 (prompt: 1663, completion: 291).
LLMMathBlockProcessor running: 72it [02:14,  1.55s/it]Azure API call successful. Total tokens used: 1744 (prompt: 1546, completion: 198).
LLMMathBlockProcessor running: 73it [02:16,  1.78s/it]Azure API call successful. Total tokens used: 1110 (prompt: 1049, completion: 61).
LLMMathBlockProcessor running: 74it [02:17,  1.36s/it]Azure API call successful. Total tokens used: 1535 (prompt: 1444, completion: 91).
LLMMathBlockProcessor running: 75it [02:18,  1.21s/it]Azure API call successful. Total tokens used: 1086 (prompt: 1048, completion: 38).
LLMMathBlockProcessor running: 76it [02:18,  1.06it/s]Azure API call successful. Total tokens used: 1094 (prompt: 1051, completion: 43).
LLMMathBlockProcessor running: 77it [02:21,  1.70s/it]Azure API call successful. Total tokens used: 1609 (prompt: 1479, completion: 130).
LLMMathBlockProcessor running: 78it [02:22,  1.44s/it]Azure API call successful. Total tokens used: 1089 (prompt: 1050, completion: 39).
LLMMathBlockProcessor running: 79it [02:23,  1.30s/it]Azure API call successful. Total tokens used: 1098 (prompt: 1053, completion: 45).
LLMMathBlockProcessor running: 80it [02:24,  1.13s/it]Azure API call successful. Total tokens used: 1530 (prompt: 1427, completion: 103).
LLMMathBlockProcessor running: 81it [02:29,  2.28s/it]Azure API call successful. Total tokens used: 2198 (prompt: 1767, completion: 431).
LLMMathBlockProcessor running: 82it [02:29,  1.72s/it]Azure API call successful. Total tokens used: 1773 (prompt: 1562, completion: 211).
LLMMathBlockProcessor running: 83it [02:30,  1.44s/it]Azure API call successful. Total tokens used: 1254 (prompt: 1224, completion: 30).
LLMMathBlockProcessor running: 84it [02:33,  1.80s/it]Azure API call successful. Total tokens used: 2245 (prompt: 1791, completion: 454).
LLMMathBlockProcessor running: 85it [02:37,  2.43s/it]Azure API call successful. Total tokens used: 1761 (prompt: 1554, completion: 207).
LLMMathBlockProcessor running: 86it [02:38,  2.16s/it]Azure API call successful. Total tokens used: 1660 (prompt: 1498, completion: 162).
LLMMathBlockProcessor running: 87it [02:40,  1.98s/it]Azure API call successful. Total tokens used: 1091 (prompt: 1051, completion: 40).
LLMMathBlockProcessor running: 88it [02:42,  1.99s/it]Azure API call successful. Total tokens used: 2409 (prompt: 1875, completion: 534).
LLMMathBlockProcessor running: 89it [02:42,  1.56s/it]Azure API call successful. Total tokens used: 1692 (prompt: 1521, completion: 171).
LLMMathBlockProcessor running: 90it [02:46,  2.15s/it]Azure API call successful. Total tokens used: 2156 (prompt: 1723, completion: 433).
LLMMathBlockProcessor running: 91it [02:46,  1.62s/it]Azure API call successful. Total tokens used: 1112 (prompt: 1055, completion: 57).
LLMMathBlockProcessor running: 92it [02:50,  2.15s/it]Azure API call successful. Total tokens used: 1854 (prompt: 1597, completion: 257).
LLMMathBlockProcessor running: 93it [02:51,  1.98s/it]Azure API call successful. Total tokens used: 1088 (prompt: 1049, completion: 39).
LLMMathBlockProcessor running: 94it [02:51,  1.45s/it]Azure API call successful. Total tokens used: 1783 (prompt: 1561, completion: 222).
LLMMathBlockProcessor running: 95it [02:53,  1.52s/it]Azure API call successful. Total tokens used: 1269 (prompt: 1226, completion: 43).
LLMMathBlockProcessor running: 96it [02:58,  2.55s/it]Azure API call successful. Total tokens used: 2486 (prompt: 1905, completion: 581).
LLMMathBlockProcessor running: 97it [03:01,  2.54s/it]Azure API call successful. Total tokens used: 1463 (prompt: 1404, completion: 59).
Azure API call successful. Total tokens used: 2226 (prompt: 1786, completion: 440).
LLMMathBlockProcessor running: 99it [03:01,  1.49s/it]Azure API call successful. Total tokens used: 1772 (prompt: 1542, completion: 230).
LLMMathBlockProcessor running: 100it [03:07,  2.53s/it]Azure API call successful. Total tokens used: 1975 (prompt: 1649, completion: 326).
LLMMathBlockProcessor running: 101it [03:08,  2.14s/it]Azure API call successful. Total tokens used: 1080 (prompt: 1052, completion: 28).
LLMMathBlockProcessor running: 102it [03:09,  1.81s/it]Azure API call successful. Total tokens used: 2141 (prompt: 1744, completion: 397).
LLMMathBlockProcessor running: 103it [03:10,  1.65s/it]Azure API call successful. Total tokens used: 1511 (prompt: 1416, completion: 95).
LLMMathBlockProcessor running: 104it [03:11,  1.37s/it]Azure API call successful. Total tokens used: 1082 (prompt: 1047, completion: 35).
LLMMathBlockProcessor running: 105it [03:14,  1.85s/it]Azure API call successful. Total tokens used: 2053 (prompt: 1693, completion: 360).
LLMMathBlockProcessor running: 106it [03:14,  1.51s/it]Azure API call successful. Total tokens used: 1093 (prompt: 1050, completion: 43).
LLMMathBlockProcessor running: 107it [03:16,  1.47s/it]Azure API call successful. Total tokens used: 1834 (prompt: 1583, completion: 251).
LLMMathBlockProcessor running: 108it [03:19,  2.03s/it]Azure API call successful. Total tokens used: 1857 (prompt: 1583, completion: 274).
LLMMathBlockProcessor running: 109it [03:25,  3.05s/it]Azure API call successful. Total tokens used: 1737 (prompt: 1543, completion: 194).
Azure API call successful. Total tokens used: 2137 (prompt: 1743, completion: 394).
LLMMathBlockProcessor running: 111it [03:28,  2.37s/it]Azure API call successful. Total tokens used: 1086 (prompt: 1048, completion: 38).
LLMMathBlockProcessor running: 112it [03:29,  2.17s/it]Azure API call successful. Total tokens used: 1802 (prompt: 1577, completion: 225).
LLMMathBlockProcessor running: 113it [03:31,  2.05s/it]Azure API call successful. Total tokens used: 1720 (prompt: 1518, completion: 202).
LLMMathBlockProcessor running: 114it [03:32,  1.75s/it]Azure API call successful. Total tokens used: 1091 (prompt: 1050, completion: 41).
LLMMathBlockProcessor running: 115it [03:33,  1.71s/it]Azure API call successful. Total tokens used: 1761 (prompt: 1545, completion: 216).
LLMMathBlockProcessor running: 116it [03:37,  2.14s/it]Azure API call successful. Total tokens used: 1742 (prompt: 1544, completion: 198).
LLMMathBlockProcessor running: 117it [03:38,  1.90s/it]Azure API call successful. Total tokens used: 1082 (prompt: 1053, completion: 29).
LLMMathBlockProcessor running: 118it [03:38,  1.40s/it]Azure API call successful. Total tokens used: 1914 (prompt: 1626, completion: 288).
LLMMathBlockProcessor running: 119it [03:39,  1.16s/it]Azure API call successful. Total tokens used: 1578 (prompt: 1461, completion: 117).
LLMMathBlockProcessor running: 120it [03:42,  1.72s/it]Azure API call successful. Total tokens used: 1476 (prompt: 1411, completion: 65).
LLMMathBlockProcessor running: 121it [03:43,  1.65s/it]Azure API call successful. Total tokens used: 1801 (prompt: 1570, completion: 231).
LLMMathBlockProcessor running: 122it [03:44,  1.31s/it]Azure API call successful. Total tokens used: 1511 (prompt: 1423, completion: 88).
LLMMathBlockProcessor running: 123it [03:47,  1.89s/it]Azure API call successful. Total tokens used: 1929 (prompt: 1602, completion: 327).
LLMMathBlockProcessor running: 124it [03:49,  1.84s/it]Azure API call successful. Total tokens used: 1492 (prompt: 1411, completion: 81).
LLMMathBlockProcessor running: 125it [03:49,  1.37s/it]Azure API call successful. Total tokens used: 1318 (prompt: 1243, completion: 75).
LLMMathBlockProcessor running: 126it [03:50,  1.18s/it]Azure API call successful. Total tokens used: 1079 (prompt: 1037, completion: 42).
LLMMathBlockProcessor running: 127it [03:51,  1.13s/it]Azure API call successful. Total tokens used: 1077 (prompt: 1046, completion: 31).
LLMMathBlockProcessor running: 128it [03:53,  1.36s/it]Azure API call successful. Total tokens used: 1555 (prompt: 1460, completion: 95).
LLMMathBlockProcessor running: 129it [03:53,  1.01s/it]Azure API call successful. Total tokens used: 1723 (prompt: 1532, completion: 191).
LLMMathBlockProcessor running: 130it [03:55,  1.27s/it]Azure API call successful. Total tokens used: 1771 (prompt: 1555, completion: 216).
LLMMathBlockProcessor running: 131it [03:59,  2.24s/it]Azure API call successful. Total tokens used: 1267 (prompt: 1225, completion: 42).
LLMMathBlockProcessor running: 132it [04:02,  2.43s/it]Azure API call successful. Total tokens used: 1939 (prompt: 1636, completion: 303).
LLMMathBlockProcessor running: 133it [04:03,  1.98s/it]Azure API call successful. Total tokens used: 1073 (prompt: 1045, completion: 28).
LLMMathBlockProcessor running: 134it [04:05,  1.86s/it]Azure API call successful. Total tokens used: 1317 (prompt: 1244, completion: 73).
LLMMathBlockProcessor running: 135it [04:05,  1.35s/it]Azure API call successful. Total tokens used: 1275 (prompt: 1221, completion: 54).
LLMMathBlockProcessor running: 136it [04:06,  1.34s/it]Azure API call successful. Total tokens used: 1089 (prompt: 1051, completion: 38).
LLMMathBlockProcessor running: 137it [04:07,  1.07s/it]Azure API call successful. Total tokens used: 1270 (prompt: 1225, completion: 45).
LLMMathBlockProcessor running: 138it [04:07,  1.19it/s]Azure API call successful. Total tokens used: 1131 (prompt: 1067, completion: 64).
LLMMathBlockProcessor running: 139it [04:08,  1.04s/it]Azure API call successful. Total tokens used: 1291 (prompt: 1234, completion: 57).
LLMMathBlockProcessor running: 140it [04:09,  1.16it/s]Azure API call successful. Total tokens used: 1262 (prompt: 1224, completion: 38).
LLMMathBlockProcessor running: 141it [04:09,  1.58it/s]Azure API call successful. Total tokens used: 1341 (prompt: 1261, completion: 80).
LLMMathBlockProcessor running: 142it [04:12,  1.24s/it]Azure API call successful. Total tokens used: 1519 (prompt: 1438, completion: 81).
LLMMathBlockProcessor running: 143it [04:12,  1.01s/it]Azure API call successful. Total tokens used: 1553 (prompt: 1450, completion: 103).
LLMMathBlockProcessor running: 144it [04:13,  1.07it/s]Azure API call successful. Total tokens used: 1471 (prompt: 1405, completion: 66).
LLMMathBlockProcessor running: 145it [04:14,  1.09s/it]Azure API call successful. Total tokens used: 1536 (prompt: 1435, completion: 101).
LLMMathBlockProcessor running: 146it [04:15,  1.16it/s]Azure API call successful. Total tokens used: 1469 (prompt: 1411, completion: 58).
LLMMathBlockProcessor running: 147it [04:16,  1.09it/s]Azure API call successful. Total tokens used: 1299 (prompt: 1238, completion: 61).
LLMMathBlockProcessor running: 148it [04:17,  1.10s/it]Azure API call successful. Total tokens used: 1651 (prompt: 1500, completion: 151).
LLMMathBlockProcessor running: 149it [04:18,  1.03it/s]Azure API call successful. Total tokens used: 1461 (prompt: 1396, completion: 65).
LLMMathBlockProcessor running: 150it [04:18,  1.25it/s]Azure API call successful. Total tokens used: 1061 (prompt: 1043, completion: 18).
LLMMathBlockProcessor running: 151it [04:20,  1.07it/s]Azure API call successful. Total tokens used: 1063 (prompt: 1040, completion: 23).
LLMMathBlockProcessor running: 152it [04:20,  1.26it/s]Azure API call successful. Total tokens used: 1278 (prompt: 1230, completion: 48).
LLMMathBlockProcessor running: 153it [04:22,  1.15s/it]Azure API call successful. Total tokens used: 1290 (prompt: 1228, completion: 62).
LLMMathBlockProcessor running: 154it [04:22,  1.07it/s]Azure API call successful. Total tokens used: 1082 (prompt: 1041, completion: 41).
LLMMathBlockProcessor running: 155it [04:23,  1.15it/s]Azure API call successful. Total tokens used: 1069 (prompt: 1043, completion: 26).
LLMMathBlockProcessor running: 156it [04:24,  1.03it/s]Azure API call successful. Total tokens used: 1604 (prompt: 1472, completion: 132).
LLMMathBlockProcessor running: 157it [04:26,  1.11s/it]Azure API call successful. Total tokens used: 1480 (prompt: 1413, completion: 67).
LLMMathBlockProcessor running: 158it [04:27,  1.21s/it]Azure API call successful. Total tokens used: 1709 (prompt: 1521, completion: 188).
LLMMathBlockProcessor running: 159it [04:28,  1.69s/it]
Saved markdown to /content/Checklist-GPT-4o-20112024/20740_Toward_Self_Improvement
Total time: 465.2165641784668"""

# Regular expression to find the lines and extract the token number
# It looks for the literal string "Azure API call successful. Tokens used: "
# followed by one or more digits (\d+), which are captured in a group ().
pattern = r"Azure API call successful. Total tokens used: (\d+)"

# Find all matches of the pattern in the log text
# re.findall returns a list of all captured groups (the numbers as strings)
token_strings = re.findall(pattern, log_text)

# Initialize the total sum
total_tokens = 0

# Iterate through the list of extracted token strings
for token_str in token_strings:
    try:
        # Convert the string to an integer and add it to the total sum
        total_tokens += int(token_str)
    except ValueError:
        # Handle cases where conversion might fail (though unlikely with this pattern)
        print(f"Warning: Could not convert '{token_str}' to an integer.")

# Print the list of extracted tokens (optional)
# print("Extracted Tokens:", token_strings)

# Print the total number of tokens found
print(f"Found {len(token_strings)} instances.")

# Print the final calculated sum
print(f"Total tokens used: {total_tokens}")
# Out:
# Found 212 instances.
# Total tokens used: 331020
