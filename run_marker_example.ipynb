# %%
# install dependencies
# !pip install -U torch torchvision cython
# !pip install -U 'git+https://github.com/facebookresearch/fvcore.git' 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# %%
# %reload_ext dotenv
# %dotenv

# %%
import os
AZURE_ENDPOINT = os.environ.get("AZURE_OPENAI_ENDPOINT", "YOUR_ENDPOINT_HERE")
AZURE_API_KEY = os.environ.get("AZURE_OPENAI_API_KEY", "YOUR_API_KEY_HERE")
AZURE_DEPLOYMENT_NAME = os.environ.get("AZURE_OPENAI_DEPLOYMENT_NAME", "YOUR_DEPLOYMENT_NAME_HERE") # e.g., your gpt-4o deployment
AZURE_API_VERSION = os.environ.get("AZURE_API_VERSION", "2024-05-01-preview") # Check Azure docs for the latest/best version

# %%
import subprocess

input_pdf = 'data/papers/20740_Toward_Self_Improvement.pdf'
output_dir = input_pdf.rstrip('.pdf') + "_LLM"

cmd = [
    "marker_single",
    input_pdf,
    "--output_dir", output_dir,
    "--use_llm",
    "--redo_inline_math",
    "--llm_service", "marker.services.azure_openai.AzureOpenAIService",
    "--azure_endpoint", AZURE_ENDPOINT,
    "--azure_api_key", AZURE_API_KEY,
    "--azure_deployment_name", AZURE_DEPLOYMENT_NAME,
    "--azure_api_version", AZURE_API_VERSION,
]
try:
    subprocess.run(cmd, check=True)
except subprocess.CalledProcessError as e:
    print(f"[ERROR] marker_single failed for {input_pdf}: {e}")
# Out:
# Loaded layout model s3://layout/2025_02_18 on device mps with dtype torch.float16
# Loaded texify model s3://texify/2025_02_18 on device mps with dtype torch.float16
# Loaded recognition model s3://text_recognition/2025_02_18 on device mps with dtype torch.float16
# Loaded table recognition model s3://table_recognition/2025_02_18 on device mps with dtype torch.float16
# Loaded detection model s3://text_detection/2025_02_28 on device mps with dtype torch.float16
# Loaded detection model s3://inline_math_detection/2025_02_24 on device mps with dtype torch.float16
# Recognizing layout: 100%|██████████| 5/5 [00:32<00:00,  6.49s/it]
# LLM layout relabelling: 0it [00:00, ?it/s]
# Azure API call successful. Tokens used: 9025
# LLM layout relabelling: 1it [00:03,  3.74s/it]
# Azure API call successful. Tokens used: 14667
# LLM layout relabelling: 2it [00:03,  1.66s/it]
# Azure API call successful. Tokens used: 9018
# LLM layout relabelling: 3it [00:04,  1.13s/it]
# ...

# %%
import re

# The input text containing the log messages
log_text = """
Loaded layout model s3://layout/2025_02_18 on device mps with dtype torch.float16
Loaded texify model s3://texify/2025_02_18 on device mps with dtype torch.float16Loaded recognition model s3://text_recognition/2025_02_18 on device mps with dtype torch.float16Loaded table recognition model s3://table_recognition/2025_02_18 on device mps with dtype torch.float16Loaded detection model s3://text_detection/2025_02_28 on device mps with dtype torch.float16Loaded detection model s3://inline_math_detection/2025_02_24 on device mps with dtype torch.float16
Recognizing layout: 100%|██████████| 5/5 [00:32<00:00,  6.49s/it]LLM layout relabelling: 0it [00:00, ?it/s]
Azure API call successful. Tokens used: 9025
LLM layout relabelling: 1it [00:03,  3.74s/it]
Azure API call successful. Tokens used: 14667
LLM layout relabelling: 2it [00:03,  1.66s/it]
Azure API call successful. Tokens used: 9018
LLM layout relabelling: 3it [00:04,  1.13s/it]
Azure API call successful. Tokens used: 9014
LLM layout relabelling: 4it [00:05,  1.27s/it]
Azure API call successful. Tokens used: 9001
LLM layout relabelling: 5it [00:07,  1.30s/it]
Azure API call successful. Tokens used: 9019
LLM layout relabelling: 6it [00:07,  1.28s/it]Running OCR Error Detection: 100%|██████████| 7/7 [00:06<00:00,  1.01it/s]Detecting bboxes: 100%|██████████| 7/7 [03:59<00:00, 34.14s/it]Detecting bboxes: 100%|██████████| 7/7 [02:07<00:00, 18.28s/it]Texify inference: 100%|██████████| 4/4 [02:38<00:00, 39.60s/it]Detecting bboxes: 0it [00:00, ?it/s]Recognizing tables: 100%|██████████| 2/2 [04:40<00:00, 140.15s/it]LLMTableProcessor running: 0it [00:00, ?it/s]
Azure API call successful. Tokens used: 15423
LLMTableProcessor running: 1it [00:08,  8.02s/it]
Azure API call successful. Tokens used: 9328
LLMTableProcessor running: 2it [00:12,  6.03s/it]
Azure API call successful. Tokens used: 9344
LLMTableProcessor running: 3it [00:17,  5.43s/it]
Azure API call successful. Tokens used: 15971
LLMTableProcessor running: 4it [00:18,  3.80s/it]
Azure API call successful. Tokens used: 9340
LLMTableProcessor running: 5it [00:23,  4.10s/it]
Azure API call successful. Tokens used: 17198Azure API call successful. Tokens used: 15530
LLMTableProcessor running: 6it [00:25,  3.33s/it]
Azure API call successful. Tokens used: 15043
LLMTableProcessor running: 8it [00:28,  3.58s/it]LLMTableMergeProcessor running: 0it [00:00, ?it/s]LLM processors running:   0%|          | 0/38 [00:00<?, ?it/s]
Azure API call successful. Tokens used: 21714Azure API call successful. Tokens used: 21708Azure API call successful. Tokens used: 21712
LLM processors running:   3%|▎         | 1/38 [00:10<06:27, 10.48s/it]
Azure API call successful. Tokens used: 21770
LLM processors running:  11%|█         | 4/38 [00:15<01:56,  3.43s/it]
Azure API call successful. Tokens used: 21541
LLM processors running:  13%|█▎        | 5/38 [00:17<01:32,  2.82s/it]
Azure API call successful. Tokens used: 21602
LLM processors running:  16%|█▌        | 6/38 [00:17<01:10,  2.21s/it]
Azure API call successful. Tokens used: 21973Azure API call successful. Tokens used: 21816
LLM processors running:  21%|██        | 8/38 [00:25<01:18,  2.63s/it]
Azure API call successful. Tokens used: 21844
LLM processors running:  24%|██▎       | 9/38 [00:27<01:17,  2.67s/it]
Azure API call successful. Tokens used: 21376Azure API call successful. Tokens used: 21594Azure API call successful. Tokens used: 21341
LLM processors running:  26%|██▋       | 10/38 [00:36<02:05,  4.47s/it]
Azure API call successful. Tokens used: 21676
LLM processors running:  34%|███▍      | 13/38 [00:40<01:07,  2.69s/it]
Azure API call successful. Tokens used: 21473
LLM processors running:  37%|███▋      | 14/38 [00:42<01:00,  2.53s/it]
Azure API call successful. Tokens used: 21628
LLM processors running:  39%|███▉      | 15/38 [00:43<00:50,  2.20s/it]
Azure API call successful. Tokens used: 21020
LLM processors running:  42%|████▏     | 16/38 [00:45<00:48,  2.22s/it]
Azure API call successful. Tokens used: 9238
LLM processors running:  45%|████▍     | 17/38 [00:46<00:39,  1.87s/it]
Azure API call successful. Tokens used: 14915
LLM processors running:  47%|████▋     | 18/38 [00:47<00:34,  1.73s/it]
Azure API call successful. Tokens used: 9137Azure API call successful. Tokens used: 9350
LLM processors running:  50%|█████     | 19/38 [00:50<00:36,  1.92s/it]
Azure API call successful. Tokens used: 9394
LLM processors running:  55%|█████▌    | 21/38 [00:53<00:28,  1.69s/it]
Azure API call successful. Tokens used: 9128Azure API call successful. Tokens used: 9284
LLM processors running:  61%|██████    | 23/38 [00:53<00:16,  1.07s/it]
Azure API call successful. Tokens used: 9111Azure API call successful. Tokens used: 9146
LLM processors running:  63%|██████▎   | 24/38 [00:57<00:23,  1.67s/it]
Azure API call successful. Tokens used: 9138
LLM processors running:  66%|██████▌   | 25/38 [00:57<00:16,  1.30s/it]
Azure API call successful. Tokens used: 9125Azure API call successful. Tokens used: 9163
LLM processors running:  71%|███████   | 27/38 [01:00<00:16,  1.47s/it]
Azure API call successful. Tokens used: 9241
LLM processors running:  76%|███████▋  | 29/38 [01:01<00:08,  1.04it/s]
Azure API call successful. Tokens used: 9203Azure API call successful. Tokens used: 9187
LLM processors running:  82%|████████▏ | 31/38 [01:03<00:07,  1.02s/it]
Azure API call successful. Tokens used: 9246
LLM processors running:  84%|████████▍ | 32/38 [01:05<00:07,  1.23s/it]
Azure API call successful. Tokens used: 9139Azure API call successful. Tokens used: 9220
LLM processors running:  89%|████████▉ | 34/38 [01:07<00:04,  1.02s/it]
Azure API call successful. Tokens used: 9135
LLM processors running:  92%|█████████▏| 35/38 [01:09<00:04,  1.42s/it]
Azure API call successful. Tokens used: 8857Azure API call successful. Tokens used: 9252
LLM processors running:  95%|█████████▍| 36/38 [01:11<00:02,  1.49s/it]
Azure API call successful. Tokens used: 8874
LLM processors running: 100%|██████████| 38/38 [01:12<00:00,  1.91s/it]LLMMathBlockProcessor running: 0it [00:00, ?it/s]
Azure API call successful. Tokens used: 20910
LLMMathBlockProcessor running: 1it [00:05,  5.70s/it]
Azure API call successful. Tokens used: 20985
LLMMathBlockProcessor running: 2it [00:11,  5.69s/it]
Azure API call successful. Tokens used: 21226
LLMMathBlockProcessor running: 3it [00:11,  3.27s/it]
Azure API call successful. Tokens used: 21306
LLMMathBlockProcessor running: 4it [00:12,  2.13s/it]
Azure API call successful. Tokens used: 20863Azure API call successful. Tokens used: 21030
LLMMathBlockProcessor running: 5it [00:17,  3.14s/it]
Azure API call successful. Tokens used: 21546
LLMMathBlockProcessor running: 7it [00:21,  2.74s/it]
Azure API call successful. Tokens used: 21660
LLMMathBlockProcessor running: 8it [00:25,  3.11s/it]
Azure API call successful. Tokens used: 20945
LLMMathBlockProcessor running: 9it [00:27,  2.72s/it]
Azure API call successful. Tokens used: 21481
LLMMathBlockProcessor running: 10it [00:27,  2.05s/it]
Azure API call successful. Tokens used: 21006
LLMMathBlockProcessor running: 11it [00:33,  3.04s/it]
Azure API call successful. Tokens used: 21228
LLMMathBlockProcessor running: 12it [00:33,  2.29s/it]
Azure API call successful. Tokens used: 21197
LLMMathBlockProcessor running: 13it [00:34,  1.73s/it]
Azure API call successful. Tokens used: 21056
LLMMathBlockProcessor running: 14it [00:40,  2.91s/it]
Azure API call successful. Tokens used: 21542
LLMMathBlockProcessor running: 15it [00:42,  2.72s/it]
Azure API call successful. Tokens used: 21753
LLMMathBlockProcessor running: 16it [00:43,  2.24s/it]
Azure API call successful. Tokens used: 21512
LLMMathBlockProcessor running: 17it [00:49,  3.38s/it]
Azure API call successful. Tokens used: 21288
LLMMathBlockProcessor running: 18it [00:51,  2.89s/it]
Azure API call successful. Tokens used: 21134
LLMMathBlockProcessor running: 19it [00:52,  2.49s/it]
Azure API call successful. Tokens used: 21115
LLMMathBlockProcessor running: 20it [00:54,  2.31s/it]
Azure API call successful. Tokens used: 21245
LLMMathBlockProcessor running: 21it [00:58,  2.69s/it]
Azure API call successful. Tokens used: 21037Azure API call successful. Tokens used: 21202
LLMMathBlockProcessor running: 22it [00:59,  2.27s/it]
Azure API call successful. Tokens used: 15052
LLMMathBlockProcessor running: 24it [01:02,  1.80s/it]
Azure API call successful. Tokens used: 15127
LLMMathBlockProcessor running: 25it [01:04,  1.87s/it]
Azure API call successful. Tokens used: 20756
LLMMathBlockProcessor running: 26it [01:04,  1.59s/it]
Azure API call successful. Tokens used: 20856
LLMMathBlockProcessor running: 27it [01:06,  1.69s/it]
Azure API call successful. Tokens used: 20805
LLMMathBlockProcessor running: 28it [01:08,  1.61s/it]
Azure API call successful. Tokens used: 20922
LLMMathBlockProcessor running: 29it [01:09,  1.58s/it]
Azure API call successful. Tokens used: 20906
LLMMathBlockProcessor running: 30it [01:11,  1.62s/it]
Azure API call successful. Tokens used: 21011
LLMMathBlockProcessor running: 31it [01:13,  1.72s/it]
Azure API call successful. Tokens used: 15266
LLMMathBlockProcessor running: 32it [01:14,  1.57s/it]
Azure API call successful. Tokens used: 15196
LLMMathBlockProcessor running: 33it [01:16,  1.51s/it]
Azure API call successful. Tokens used: 15282
LLMMathBlockProcessor running: 34it [01:18,  1.90s/it]
Azure API call successful. Tokens used: 21254
LLMMathBlockProcessor running: 35it [01:21,  2.04s/it]
Azure API call successful. Tokens used: 21476Azure API call successful. Tokens used: 20864
LLMMathBlockProcessor running: 36it [01:24,  2.37s/it]
Azure API call successful. Tokens used: 21068
LLMMathBlockProcessor running: 38it [01:27,  2.08s/it]
Azure API call successful. Tokens used: 21124
LLMMathBlockProcessor running: 39it [01:30,  2.11s/it]
Azure API call successful. Tokens used: 21099
LLMMathBlockProcessor running: 40it [01:30,  1.75s/it]
Azure API call successful. Tokens used: 21486Azure API call successful. Tokens used: 21135
LLMMathBlockProcessor running: 41it [01:35,  2.57s/it]
Azure API call successful. Tokens used: 21182
LLMMathBlockProcessor running: 43it [01:37,  1.90s/it]
Azure API call successful. Tokens used: 20888
LLMMathBlockProcessor running: 44it [01:39,  2.00s/it]
Azure API call successful. Tokens used: 21072
LLMMathBlockProcessor running: 45it [01:41,  1.94s/it]
Azure API call successful. Tokens used: 20857
LLMMathBlockProcessor running: 46it [01:42,  1.57s/it]
Azure API call successful. Tokens used: 15046
LLMMathBlockProcessor running: 47it [01:45,  1.99s/it]
Azure API call successful. Tokens used: 21144
LLMMathBlockProcessor running: 48it [01:47,  1.90s/it]
Azure API call successful. Tokens used: 21172
LLMMathBlockProcessor running: 49it [01:48,  1.80s/it]
Azure API call successful. Tokens used: 20865
LLMMathBlockProcessor running: 50it [01:48,  1.40s/it]
Azure API call successful. Tokens used: 20984
LLMMathBlockProcessor running: 51it [01:52,  2.00s/it]
Azure API call successful. Tokens used: 20789
LLMMathBlockProcessor running: 52it [01:52,  1.52s/it]
Azure API call successful. Tokens used: 15022
LLMMathBlockProcessor running: 53it [01:55,  1.94s/it]
Azure API call successful. Tokens used: 20813
LLMMathBlockProcessor running: 54it [01:56,  1.66s/it]
Azure API call successful. Tokens used: 21081
LLMMathBlockProcessor running: 55it [01:58,  1.74s/it]
Azure API call successful. Tokens used: 15130
LLMMathBlockProcessor running: 56it [02:00,  1.64s/it]
Azure API call successful. Tokens used: 15035
LLMMathBlockProcessor running: 57it [02:00,  1.23s/it]
Azure API call successful. Tokens used: 15080
LLMMathBlockProcessor running: 58it [02:03,  1.71s/it]
Azure API call successful. Tokens used: 20722
LLMMathBlockProcessor running: 59it [02:03,  1.39s/it]
Azure API call successful. Tokens used: 15031
LLMMathBlockProcessor running: 60it [02:06,  1.79s/it]
Azure API call successful. Tokens used: 15045Azure API call successful. Tokens used: 9363
LLMMathBlockProcessor running: 61it [02:06,  1.39s/it]
Azure API call successful. Tokens used: 20734
LLMMathBlockProcessor running: 63it [02:10,  1.48s/it]
Azure API call successful. Tokens used: 15160
LLMMathBlockProcessor running: 64it [02:11,  1.49s/it]
Azure API call successful. Tokens used: 20761
LLMMathBlockProcessor running: 65it [02:12,  1.44s/it]
Azure API call successful. Tokens used: 21342
LLMMathBlockProcessor running: 66it [02:14,  1.55s/it]
Azure API call successful. Tokens used: 21389
LLMMathBlockProcessor running: 67it [02:19,  2.33s/it]
Azure API call successful. Tokens used: 21299
LLMMathBlockProcessor running: 68it [02:19,  1.88s/it]
Azure API call successful. Tokens used: 21513
LLMMathBlockProcessor running: 69it [02:22,  2.12s/it]
Azure API call successful. Tokens used: 20867
LLMMathBlockProcessor running: 70it [02:23,  1.80s/it]
Azure API call successful. Tokens used: 9325
LLMMathBlockProcessor running: 71it [02:25,  1.81s/it]
Azure API call successful. Tokens used: 21261
LLMMathBlockProcessor running: 72it [02:26,  1.68s/it]
Azure API call successful. Tokens used: 21037Azure API call successful. Tokens used: 20867Azure API call successful. Tokens used: 9359
LLMMathBlockProcessor running: 73it [02:30,  2.15s/it]
Azure API call successful. Tokens used: 9398
LLMMathBlockProcessor running: 76it [02:33,  1.60s/it]
Azure API call successful. Tokens used: 9389
LLMMathBlockProcessor running: 77it [02:34,  1.38s/it]
Azure API call successful. Tokens used: 20871
LLMMathBlockProcessor running: 78it [02:35,  1.37s/it]
Azure API call successful. Tokens used: 9366
LLMMathBlockProcessor running: 79it [02:37,  1.49s/it]
Azure API call successful. Tokens used: 9357
LLMMathBlockProcessor running: 80it [02:38,  1.41s/it]
Azure API call successful. Tokens used: 21498
LLMMathBlockProcessor running: 81it [02:41,  1.82s/it]
Azure API call successful. Tokens used: 20783
LLMMathBlockProcessor running: 82it [02:43,  1.74s/it]
Azure API call successful. Tokens used: 21065
LLMMathBlockProcessor running: 83it [02:43,  1.45s/it]
Azure API call successful. Tokens used: 15043
LLMMathBlockProcessor running: 84it [02:47,  2.01s/it]
Azure API call successful. Tokens used: 21034
LLMMathBlockProcessor running: 85it [02:48,  1.93s/it]
Azure API call successful. Tokens used: 21460
LLMMathBlockProcessor running: 86it [02:49,  1.56s/it]
Azure API call successful. Tokens used: 21033
LLMMathBlockProcessor running: 87it [02:54,  2.47s/it]
Azure API call successful. Tokens used: 21285
LLMMathBlockProcessor running: 88it [02:56,  2.29s/it]
Azure API call successful. Tokens used: 21781
LLMMathBlockProcessor running: 89it [02:56,  1.69s/it]
Azure API call successful. Tokens used: 9363
LLMMathBlockProcessor running: 90it [02:57,  1.64s/it]
Azure API call successful. Tokens used: 9340Azure API call successful. Tokens used: 20971
LLMMathBlockProcessor running: 91it [03:00,  2.08s/it]
Azure API call successful. Tokens used: 9331
LLMMathBlockProcessor running: 93it [03:04,  2.02s/it]
Azure API call successful. Tokens used: 21118
LLMMathBlockProcessor running: 94it [03:07,  2.16s/it]
Azure API call successful. Tokens used: 21080Azure API call successful. Tokens used: 15041
LLMMathBlockProcessor running: 96it [03:08,  1.33s/it]
Azure API call successful. Tokens used: 20708
LLMMathBlockProcessor running: 97it [03:12,  2.12s/it]
Azure API call successful. Tokens used: 21652
LLMMathBlockProcessor running: 98it [03:17,  2.98s/it]
Azure API call successful. Tokens used: 21062
LLMMathBlockProcessor running: 99it [03:17,  2.23s/it]
Azure API call successful. Tokens used: 21997
LLMMathBlockProcessor running: 100it [03:22,  2.90s/it]
Azure API call successful. Tokens used: 21167
LLMMathBlockProcessor running: 101it [03:23,  2.41s/it]
Azure API call successful. Tokens used: 9335
LLMMathBlockProcessor running: 102it [03:25,  2.18s/it]
Azure API call successful. Tokens used: 21476
LLMMathBlockProcessor running: 103it [03:25,  1.65s/it]
Azure API call successful. Tokens used: 20791
LLMMathBlockProcessor running: 104it [03:27,  1.82s/it]
Azure API call successful. Tokens used: 9334
LLMMathBlockProcessor running: 105it [03:31,  2.24s/it]
Azure API call successful. Tokens used: 21082
LLMMathBlockProcessor running: 106it [03:31,  1.75s/it]
Azure API call successful. Tokens used: 21332
LLMMathBlockProcessor running: 107it [03:32,  1.42s/it]
Azure API call successful. Tokens used: 9334
LLMMathBlockProcessor running: 108it [03:33,  1.18s/it]
Azure API call successful. Tokens used: 21189
LLMMathBlockProcessor running: 109it [03:38,  2.32s/it]
Azure API call successful. Tokens used: 21083
LLMMathBlockProcessor running: 110it [03:38,  1.73s/it]
Azure API call successful. Tokens used: 21533
LLMMathBlockProcessor running: 111it [03:40,  1.79s/it]
Azure API call successful. Tokens used: 9336
LLMMathBlockProcessor running: 112it [03:43,  2.18s/it]
Azure API call successful. Tokens used: 20976
LLMMathBlockProcessor running: 113it [03:43,  1.60s/it]
Azure API call successful. Tokens used: 21142
LLMMathBlockProcessor running: 114it [03:44,  1.26s/it]
Azure API call successful. Tokens used: 9315
LLMMathBlockProcessor running: 115it [03:46,  1.65s/it]
Azure API call successful. Tokens used: 21180
LLMMathBlockProcessor running: 116it [03:49,  2.12s/it]
Azure API call successful. Tokens used: 21139
LLMMathBlockProcessor running: 117it [03:50,  1.69s/it]
Azure API call successful. Tokens used: 20976
LLMMathBlockProcessor running: 118it [03:52,  1.65s/it]
Azure API call successful. Tokens used: 9330
LLMMathBlockProcessor running: 119it [03:52,  1.36s/it]
Azure API call successful. Tokens used: 20894
LLMMathBlockProcessor running: 120it [03:55,  1.73s/it]
Azure API call successful. Tokens used: 20794
LLMMathBlockProcessor running: 121it [03:57,  1.70s/it]
Azure API call successful. Tokens used: 21204
LLMMathBlockProcessor running: 122it [03:59,  1.96s/it]
Azure API call successful. Tokens used: 20742
LLMMathBlockProcessor running: 123it [04:01,  1.79s/it]
Azure API call successful. Tokens used: 21164
LLMMathBlockProcessor running: 124it [04:02,  1.72s/it]
Azure API call successful. Tokens used: 20759
LLMMathBlockProcessor running: 125it [04:03,  1.51s/it]
Azure API call successful. Tokens used: 15065
LLMMathBlockProcessor running: 126it [04:05,  1.59s/it]
Azure API call successful. Tokens used: 9368
LLMMathBlockProcessor running: 127it [04:06,  1.54s/it]
Azure API call successful. Tokens used: 20819
LLMMathBlockProcessor running: 128it [04:08,  1.66s/it]
Azure API call successful. Tokens used: 9351
LLMMathBlockProcessor running: 129it [04:10,  1.60s/it]
Azure API call successful. Tokens used: 20989
LLMMathBlockProcessor running: 130it [04:10,  1.20s/it]
Azure API call successful. Tokens used: 15012
LLMMathBlockProcessor running: 131it [04:13,  1.83s/it]
Azure API call successful. Tokens used: 21102
LLMMathBlockProcessor running: 132it [04:14,  1.56s/it]
Azure API call successful. Tokens used: 21070
LLMMathBlockProcessor running: 133it [04:15,  1.30s/it]
Azure API call successful. Tokens used: 15024
LLMMathBlockProcessor running: 134it [04:17,  1.47s/it]
Azure API call successful. Tokens used: 9317
LLMMathBlockProcessor running: 135it [04:18,  1.36s/it]
Azure API call successful. Tokens used: 15104
LLMMathBlockProcessor running: 136it [04:18,  1.05s/it]
Azure API call successful. Tokens used: 15015
LLMMathBlockProcessor running: 137it [04:20,  1.26s/it]
Azure API call successful. Tokens used: 9383Azure API call successful. Tokens used: 15069
LLMMathBlockProcessor running: 138it [04:22,  1.41s/it]
Azure API call successful. Tokens used: 9341
LLMMathBlockProcessor running: 140it [04:23,  1.01it/s]
Azure API call successful. Tokens used: 15009
LLMMathBlockProcessor running: 141it [04:25,  1.33s/it]
Azure API call successful. Tokens used: 20795
LLMMathBlockProcessor running: 142it [04:26,  1.23s/it]
Azure API call successful. Tokens used: 15130
LLMMathBlockProcessor running: 143it [04:27,  1.04s/it]
Azure API call successful. Tokens used: 20800
LLMMathBlockProcessor running: 144it [04:30,  1.63s/it]
Azure API call successful. Tokens used: 20728
LLMMathBlockProcessor running: 145it [04:30,  1.32s/it]
Azure API call successful. Tokens used: 20861
LLMMathBlockProcessor running: 146it [04:31,  1.07s/it]
Azure API call successful. Tokens used: 20738
LLMMathBlockProcessor running: 147it [04:34,  1.71s/it]
Azure API call successful. Tokens used: 15050
LLMMathBlockProcessor running: 148it [04:35,  1.41s/it]
Azure API call successful. Tokens used: 20954
LLMMathBlockProcessor running: 149it [04:35,  1.13s/it]
Azure API call successful. Tokens used: 9294
LLMMathBlockProcessor running: 150it [04:38,  1.55s/it]
Azure API call successful. Tokens used: 9308Azure API call successful. Tokens used: 20697
LLMMathBlockProcessor running: 151it [04:38,  1.25s/it]
Azure API call successful. Tokens used: 9296
LLMMathBlockProcessor running: 153it [04:40,  1.20s/it]
Azure API call successful. Tokens used: 15052
LLMMathBlockProcessor running: 154it [04:42,  1.24s/it]
Azure API call successful. Tokens used: 9299Azure API call successful. Tokens used: 20880
LLMMathBlockProcessor running: 156it [04:45,  1.26s/it]
Azure API call successful. Tokens used: 15056
LLMMathBlockProcessor running: 157it [04:45,  1.06s/it]
Azure API call successful. Tokens used: 20760
LLMMathBlockProcessor running: 158it [04:49,  1.77s/it]
Azure API call successful. Tokens used: 20995
LLMMathBlockProcessor running: 159it [04:50,  1.83s/it]
Saved markdown to data/papers/20740_Toward_Self_Improvement_LLM/20740_Toward_Self_ImprovementTotal time: 1268.7391691207886
"""

# Regular expression to find the lines and extract the token number
# It looks for the literal string "Azure API call successful. Tokens used: "
# followed by one or more digits (\d+), which are captured in a group ().
pattern = r"Azure API call successful\. Tokens used: (\d+)"

# Find all matches of the pattern in the log text
# re.findall returns a list of all captured groups (the numbers as strings)
token_strings = re.findall(pattern, log_text)

# Initialize the total sum
total_tokens = 0

# Iterate through the list of extracted token strings
for token_str in token_strings:
    try:
        # Convert the string to an integer and add it to the total sum
        total_tokens += int(token_str)
    except ValueError:
        # Handle cases where conversion might fail (though unlikely with this pattern)
        print(f"Warning: Could not convert '{token_str}' to an integer.")

# Print the list of extracted tokens (optional)
# print("Extracted Tokens:", token_strings)

# Print the total number of tokens found
print(f"Found {len(token_strings)} instances.")

# Print the final calculated sum
print(f"Total tokens used: {total_tokens}")
# Out:
# Found 211 instances.
# Total tokens used: 3623743

# %%
import subprocess

input_pdf = 'data/papers/20740_Toward_Self_Improvement.pdf'
output_dir = input_pdf.rstrip('.pdf') + "_paginate_ocr"

cmd = [
    "marker_single",
    input_pdf,
    "--output_dir", output_dir,
    "--paginate_output",
    "--force_ocr",
]
try:
    subprocess.run(cmd, check=True)
except subprocess.CalledProcessError as e:
    print(f"[ERROR] marker_single failed for {input_pdf}: {e}")
# Out:
# Loaded layout model s3://layout/2025_02_18 on device mps with dtype torch.float16
# Loaded texify model s3://texify/2025_02_18 on device mps with dtype torch.float16
# Loaded recognition model s3://text_recognition/2025_02_18 on device mps with dtype torch.float16
# Loaded table recognition model s3://table_recognition/2025_02_18 on device mps with dtype torch.float16
# Loaded detection model s3://text_detection/2025_02_28 on device mps with dtype torch.float16
# Loaded detection model s3://inline_math_detection/2025_02_24 on device mps with dtype torch.float16
# ...
# Recognizing Text:   0%|          | 0/39 [00:00<?, ?it/s]

# %%
import re

# The input text containing the log messages
log_text = """
  Recognizing layout: 100% 5/5 [00:05<00:00,  1.01s/it]
LLM layout relabelling: 0it [00:00, ?it/s]Azure API call successful. Tokens used: 750
LLM layout relabelling: 1it [00:01,  1.79s/it]Azure API call successful. Tokens used: 740
LLM layout relabelling: 2it [00:02,  1.09s/it]Azure API call successful. Tokens used: 726
LLM layout relabelling: 3it [00:02,  1.20it/s]Azure API call successful. Tokens used: 732
LLM layout relabelling: 4it [00:04,  1.00it/s]Azure API call successful. Tokens used: 748
LLM layout relabelling: 5it [00:05,  1.11s/it]Azure API call successful. Tokens used: 732
LLM layout relabelling: 6it [00:06,  1.21s/it]Azure API call successful. Tokens used: 913
LLM layout relabelling: 7it [00:11,  2.41s/it]Azure API call successful. Tokens used: 724
LLM layout relabelling: 8it [00:12,  1.58s/it]
Running OCR Error Detection: 100% 7/7 [00:00<00:00, 40.58it/s]
Detecting bboxes: 100% 7/7 [00:05<00:00,  1.17it/s]
Detecting bboxes: 100% 7/7 [00:05<00:00,  1.30it/s]
Texify inference: 100% 4/4 [00:04<00:00,  1.06s/it]
Detecting bboxes: 0it [00:00, ?it/s]
Recognizing tables: 100% 2/2 [00:01<00:00,  1.85it/s]
LLMTableProcessor running: 0it [00:00, ?it/s]Azure API call successful. Tokens used: 2040
LLMTableProcessor running: 1it [00:07,  7.12s/it]Azure API call successful. Tokens used: 1190
LLMTableProcessor running: 2it [00:09,  4.20s/it]Azure API call successful. Tokens used: 1947
LLMTableProcessor running: 3it [00:10,  2.78s/it]Azure API call successful. Tokens used: 1039
LLMTableProcessor running: 4it [00:11,  2.06s/it]Azure API call successful. Tokens used: 1083
LLMTableProcessor running: 5it [00:14,  2.34s/it]Azure API call successful. Tokens used: 1882
LLMTableProcessor running: 6it [00:15,  2.09s/it]Azure API call successful. Tokens used: 1207
LLMTableProcessor running: 7it [00:16,  1.64s/it]Azure API call successful. Tokens used: 1713
LLMTableProcessor running: 8it [00:20,  2.62s/it]
LLMTableMergeProcessor running: 0it [00:00, ?it/s]
LLM processors running:   0% 0/17 [00:00<?, ?it/s]Azure API call successful. Tokens used: 2482
Azure API call successful. Tokens used: 2403
Azure API call successful. Tokens used: 2394
LLM processors running:   6% 1/17 [00:08<02:19,  8.74s/it]Azure API call successful. Tokens used: 2454
LLM processors running:  24% 4/17 [00:13<00:37,  2.90s/it]Azure API call successful. Tokens used: 2321
LLM processors running:  29% 5/17 [00:14<00:28,  2.40s/it]Azure API call successful. Tokens used: 2374
Azure API call successful. Tokens used: 2712
LLM processors running:  41% 7/17 [00:20<00:26,  2.66s/it]Azure API call successful. Tokens used: 2492
Azure API call successful. Tokens used: 2488
LLM processors running:  47% 8/17 [00:20<00:18,  2.06s/it]Azure API call successful. Tokens used: 2047
LLM processors running:  59% 10/17 [00:31<00:24,  3.44s/it]Azure API call successful. Tokens used: 2143
LLM processors running:  65% 11/17 [00:33<00:18,  3.01s/it]Azure API call successful. Tokens used: 2332
LLM processors running:  71% 12/17 [00:33<00:11,  2.33s/it]Azure API call successful. Tokens used: 2351
LLM processors running:  76% 13/17 [00:36<00:10,  2.64s/it]Azure API call successful. Tokens used: 2209
LLM processors running:  82% 14/17 [00:39<00:07,  2.53s/it]Azure API call successful. Tokens used: 2320
LLM processors running:  88% 15/17 [00:39<00:03,  1.96s/it]Azure API call successful. Tokens used: 1771
LLM processors running:  94% 16/17 [00:40<00:01,  1.64s/it]Azure API call successful. Tokens used: 620
LLM processors running: 100% 17/17 [00:41<00:00,  2.46s/it]
Saved markdown to /content/Checklist-GPT-4-0125-Preview/20740_Toward_Self_Improvement
Total time: 112.78809881210327"""

# Regular expression to find the lines and extract the token number
# It looks for the literal string "Azure API call successful. Tokens used: "
# followed by one or more digits (\d+), which are captured in a group ().
pattern = r"Azure API call successful\. Tokens used: (\d+)"

# Find all matches of the pattern in the log text
# re.findall returns a list of all captured groups (the numbers as strings)
token_strings = re.findall(pattern, log_text)

# Initialize the total sum
total_tokens = 0

# Iterate through the list of extracted token strings
for token_str in token_strings:
    try:
        # Convert the string to an integer and add it to the total sum
        total_tokens += int(token_str)
    except ValueError:
        # Handle cases where conversion might fail (though unlikely with this pattern)
        print(f"Warning: Could not convert '{token_str}' to an integer.")

# Print the list of extracted tokens (optional)
# print("Extracted Tokens:", token_strings)

# Print the total number of tokens found
print(f"Found {len(token_strings)} instances.")

# Print the final calculated sum
print(f"Total tokens used: {total_tokens}")
# Out:
# Found 33 instances.
# Total tokens used: 56079
